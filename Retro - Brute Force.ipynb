# %% [markdown]
# #Brute Force Agent
# This is a agent that utlized the brute force algorithm provided by Gym Retro examples.
#
# The brute force algorithm relies on the determinism of the environment in order to brute force the best sequence of actions. It does not save emulator state but saves the action sequence that led to the best outcome.

# %% [markdown]
# #Mount Google Drive

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# TensorFlow 2.x selected.
# Note: using Google CoLab

# %% [markdown]
# #Install Retro & Imports

# %%
# !pip3 install gym-retro # install OpenAI Gym-Retro
# Out:
# Collecting gym-retro
#   Downloading https://files.pythonhosted.org/packages/73/6d/2c9f009663b74bcf66a2306c2b8a819a1ac6b0d3090e342720291b527446/gym_retro-0.7.1-cp36-cp36m-manylinux1_x86_64.whl (162.0MB)
#      |████████████████████████████████| 162.0MB 57kB/s
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from gym-retro) (0.15.6)
# Requirement already satisfied: pyglet==1.*,>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from gym-retro) (1.4.10)
# Requirement already satisfied: numpy>=1.10.4 in /tensorflow-2.1.0/python3.6 (from gym->gym-retro) (1.18.1)
# Requirement already satisfied: six in /tensorflow-2.1.0/python3.6 (from gym->gym-retro) (1.14.0)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->gym-retro) (1.2.2)
# Requirement already satisfied: scipy in /tensorflow-2.1.0/python3.6 (from gym->gym-retro) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet==1.*,>=1.3.2->gym-retro) (0.16.0)
# Installing collected packages: gym-retro
# Successfully installed gym-retro-0.7.1

# %%
import gym
import retro
import numpy as np
import matplotlib.pyplot as plt
import imageio
import cv2
import os
from datetime import datetime, timedelta
from time import time

# %% [markdown]
# #Install Roms

# %%
# install roms
romPath = '/content/drive/My Drive/Colab Notebooks/Roms/'
for rom in os.listdir(romPath):
  retro.data.merge(romPath + rom, quiet=False)
# Out:
# Importing SpaceInvaders-Nes
# Imported 1 games
# Importing Joust-Nes
# Imported 1 games
# Importing SuperMarioBros-Nes
# Imported 1 games
# Importing MsPacMan-Nes
# Imported 1 games

# %% [markdown]
# #Environment Wrappers

# %%
# Discretize continuous action space
class Discretizer(gym.ActionWrapper):
  def __init__(self, env, combos):
    super().__init__(env)
    assert isinstance(env.action_space, gym.spaces.MultiBinary)
    buttons = env.unwrapped.buttons
    self._decode_discrete_action = []
    for combo in combos:
      arr = np.array([False] * env.action_space.n)
      for button in combo:
        arr[buttons.index(button)] = True
      self._decode_discrete_action.append(arr)

    self.action_space = gym.spaces.Discrete(len(self._decode_discrete_action))

  def action(self, act):
    return self._decode_discrete_action[act].copy()

# Limit the episode length
class TimeLimit(gym.Wrapper):
  def __init__(self, env, max_episode_steps=None):
    super().__init__(env)
    self._max_episode_steps = max_episode_steps
    self._elapsed_steps = 0

  def step(self, action):
    obs, reward, done, info = self.env.step(action)
    self._elapsed_steps += 1
    if self._elapsed_steps >= self._max_episode_steps:
      done = True
      info['TimeLimit.truncated'] = True
    return obs, reward, done, info

  def reset(self, **kwargs):
    self._elapsed_steps = 0
    return self.env.reset(**kwargs)

# Skip frames
class SkipFrames(gym.Wrapper):
  def __init__(self, env, n = 4):
    gym.Wrapper.__init__(self, env)
    self.n = n

  def step(self, action):
    done = False
    totalReward = 0.0
    for _ in range(self.n):
      obs, reward, done, info = self.env.step(action)
      totalReward += reward
      if done:
        break
    return obs, totalReward, done, info

# combine the wrappers
def make_env(game, state, scenario, record, obs_type, combos, timeLimit):
  env = retro.make(game=game, state=state, scenario=scenario, record=record, obs_type=obs_type)
  env = Discretizer(env, combos=combos)
  env = TimeLimit(env, timeLimit)
  env = SkipFrames(env)
  return env

# %% [markdown]
# #Utility functions

# %%
# Render avi or gif
def renderFrames(frame_array, savePath, fileName, fps, otype='AVI'):
  print('Converting frames to .{} ...'.format(otype), end=' ')
  if otype == 'AVI':
    fileName += '.avi'
    height, width, layers = frame_array[0].shape
    if layers == 1:
      layers = 0
    size = (width, height)
    out = cv2.VideoWriter(savePath + fileName, cv2.VideoWriter_fourcc(*'DIVX'), fps, size, layers)
    for i in range(len(frame_array)):
      out.write(frame_array[i])
    out.release()
    print('Done. Saved to {}'.format(savePath + fileName))
  elif otype == 'GIF':
    fileName += '.gif'
    imageio.mimwrite(savePath + fileName, replay, fps=fps)
    print('Done. Saved to {}'.format(savePath + fileName))
  else:
    print('Error: Invalid type, must be GIF or AVI.')

# Get current date/time foramtted as string
def Now():
  # subtract 6 hours to get correct tz
  now = datetime.now() - timedelta(hours=6)
  return now.strftime('%m_%d_%Y_%H%M%S')

# save the log to file
def saveLog(savePath, fileName, log):
  print('Saving log ...', end=' ')
  fileName += '.log'
  f = open(savePath + fileName, 'w')
  for line in log:
    f.write(line + '\n')
  f.write(Now())
  f.close()
  print('Done. Saved to {}'.format(savePath + fileName))

# %% [markdown]
# #Agent
# Brute force agent modeled after code found here: [Brute Algorithm](https://github.com/openai/retro/blob/master/retro/examples/brute.py)

# %%
class Node:
  def __init__(self, value=-np.inf, children=None):
    self.value = value
    self.visits = 0
    self.children = {} if children is None else children

  def __repr__(self):
    return '<Node value={%f} visits={%d} len(children)={%d}>'.format(
      self.value,
      self.visits,
      len(self.children) )
    
class Results:
  def __init__(self):
    self.episode = None
    self.score = -np.inf
    self.actions = []
    self.frames = []
    self.log = []

class Agent:
  def __init__(self, env, max_episode_steps):
    self.node_count = 1
    self._root = Node()
    self._env = env
    self._max_episode_steps = max_episode_steps
    self._EXPLORATION_PARAM = 0.005
    self.results = Results() # store the results of the best eipsode

  def _select_actions(self):
    """
    Select actions from the tree.
    Select the greedy action that has the highest reward for with subtree. 
    Small chance to select a random action based on exploration param and
    visit count of current node at each step.
    We select actions for the longest possible episode, but normally these
    will not all be used.  They will instead be truncated to the length
    of the actual episode and then used to update the tree.
    """
    node = self._root
    action_space = self._env.action_space
    actions = []
    steps = 0
    while steps < self._max_episode_steps:
      if node is None:
        # fallen off the explored area of tree, just select random actions
        action = action_space.sample()
      else:
        epsilon = self._EXPLORATION_PARAM / np.log(node.visits + 2)
        if np.random.random() < epsilon: # random action
          action = action_space.sample()
        else: # greedy action
          action_value = {}
          for action in range(action_space.n):
            if node is not None and action in node.children:
              action_value[action] = node.children[action].value
            else:
              action_value[action] = -np.inf
          best_value = max(action_value.values())
          best_actions = [
            action for action, value in action_value.items() if value == best_value
          ]
          action = np.random.choice(best_actions)

        if action in node.children:
          node = node.children[action]
        else:
          node = None
      actions.append(action)
      steps += 1
    return actions

  def _rollout(self, actions):
    """
    Perform a rollout using a preset collection of actions.
    """
    frames = []
    totalReward = 0
    self._env.reset()
    steps = 0
    for action in actions:
      obs, reward, done, _info = self._env.step(action)
      steps += 1
      totalReward += reward
      frames.append(self._env.render(mode='rgb_array'))
      if done:
        break
    return steps, totalReward, frames

  def _update_tree(self, executed_actions, totalReward):
    """
    Given the tree, a list of actions that were executed before the game ended,
    and a reward, update the tree so that the path formed by the executed
    actions are all updated to the new reward.
    """
    self._root.value = max(totalReward, self._root.value)
    self._root.visits += 1
    new_nodes = 0
    node = self._root
    for step, action in enumerate(executed_actions):
      if action not in node.children:
        node.children[action] = Node()
        new_nodes += 1
      node = node.children[action]
      node.value = max(totalReward, node.value)
      node.visits += 1
    return new_nodes

  def learn(self, numEpisodes = 1, verbose = 2):
    sTime = time()
    for i in range(numEpisodes):
      actions = self._select_actions()
      steps, totalReward, frames = self._rollout(actions)
      executed_actions = actions[:steps]
      self.node_count += self._update_tree(executed_actions, totalReward)
      logStr = 'Episode {:d}: actions={:d}, score={}, nodes={:d}'.format(
          i+1, len(executed_actions), totalReward, self.node_count)
      self.results.log.append(logStr)
      if verbose > 1:
        print(logStr)
      if totalReward > self.results.score:
        self.results.score = totalReward
        self.results.episode = i+1
        self.results.actions = executed_actions
        self.results.frames = frames
    eTime = round(time() - sTime, 4)
    logStr1 = '{} episodes ran and took {} seconds'.format(
        numEpisodes, eTime)
    logStr2 = 'Episode {:d} had the best score of {}.'.format(
        self.results.episode, self.results.score)
    self.results.log.append(logStr1)
    self.results.log.append(logStr2)
    if verbose > 0:
      if verbose > 1:
        print('-'*80)
      print(logStr1); print(logStr2);

# %% [markdown]
# #Setup

# %%
class Args:
  game = ['SpaceInvaders-Nes', 'Joust-Nes', 'SuperMarioBros-Nes', 'MsPacMan-Nes']
  combos = [ [['LEFT'], ['RIGHT'], ['A'], ['LEFT', 'A'], ['RIGHT', 'A']],
             [['LEFT'], ['RIGHT'], ['UP'], ['DOWN']] ]
  state = retro.State.DEFAULT
  scenario = 'scenario'
  record = False
  obs_type = retro.Observations.IMAGE
  savePath = '/content/drive/My Drive/Colab Notebooks/'

args = Args()

# %% [markdown]
# #Train

# %%
# you don't acually need this but usefull for debugging if env() was 
# not closed probably because bug
try:
  if env:
    env.close()
except NameError:
  pass

# 0: Space Invaders (NES) 1: Joust (NES) 2: Super Mario Bros (SNES) 3: Ms. Pacman
# 0: [LT, RT, A] 1: [LT, RT, UP, DN]
gameIndex, comboIndex, numEpisodes, maxSteps = 3, 1, 250, 10000

env = make_env(args.game[gameIndex], args.state, args.scenario, args.record,
               args.obs_type, args.combos[comboIndex], maxSteps)

agent = Agent(env, maxSteps)
agent.learn(numEpisodes=numEpisodes)

env.close()

fileName = 'Brute_' + Args.game[gameIndex] + '_E{}_{}'.format(
    agent.results.episode, Now())
renderFrames(agent.results.frames, args.savePath, fileName, 60, otype='AVI')
fileName = 'Brute_' + Args.game[gameIndex]
saveLog(args.savePath, fileName, agent.results.log)
# Out:
# Episode 1: actions=1007, score=300.0, nodes=1008
# Episode 2: actions=868, score=320.0, nodes=1415
# Episode 3: actions=772, score=310.0, nodes=1985
# Episode 4: actions=868, score=320.0, nodes=1985
# Episode 5: actions=979, score=460.0, nodes=2391
# Episode 6: actions=986, score=460.0, nodes=2640
# Episode 7: actions=936, score=370.0, nodes=3425
# Episode 8: actions=778, score=160.0, nodes=4120
# Episode 9: actions=926, score=550.0, nodes=4901
# Episode 10: actions=729, score=440.0, nodes=5321
# Episode 11: actions=926, score=550.0, nodes=5349
# Episode 12: actions=795, score=300.0, nodes=6022
# Episode 13: actions=963, score=420.0, nodes=6971
# Episode 14: actions=805, score=460.0, nodes=7409
# Episode 15: actions=758, score=400.0, nodes=8165
# Episode 16: actions=806, score=440.0, nodes=8688
# Episode 17: actions=850, score=440.0, nodes=9228
# Episode 18: actions=735, score=280.0, nodes=9903
# Episode 19: actions=820, score=300.0, nodes=10596
# Episode 20: actions=838, score=450.0, nodes=11058
# Episode 21: actions=851, score=460.0, nodes=11193
# Episode 22: actions=801, score=310.0, nodes=11961
# Episode 23: actions=926, score=550.0, nodes=11961
# Episode 24: actions=1007, score=510.0, nodes=12455
# Episode 25: actions=770, score=300.0, nodes=13020
# Episode 26: actions=926, score=550.0, nodes=13020
# Episode 27: actions=1091, score=590.0, nodes=13660
# Episode 28: actions=743, score=310.0, nodes=14006
# Episode 29: actions=1018, score=460.0, nodes=14216
# Episode 30: actions=1091, score=590.0, nodes=14216
# Episode 31: actions=1080, score=720.0, nodes=14801
# Episode 32: actions=987, score=500.0, nodes=15320
# Episode 33: actions=740, score=190.0, nodes=15959
# Episode 34: actions=1127, score=720.0, nodes=16408
# Episode 35: actions=884, score=370.0, nodes=17046
# Episode 36: actions=788, score=300.0, nodes=17697
# Episode 37: actions=1075, score=810.0, nodes=17900
# Episode 38: actions=945, score=460.0, nodes=18786
# Episode 39: actions=737, score=310.0, nodes=19437
# Episode 40: actions=933, score=430.0, nodes=20150
# Episode 41: actions=1075, score=810.0, nodes=20150
# Episode 42: actions=1075, score=810.0, nodes=20150
# Episode 43: actions=906, score=390.0, nodes=20579
# Episode 44: actions=1103, score=670.0, nodes=21116
# Episode 45: actions=813, score=420.0, nodes=21388
# Episode 46: actions=781, score=440.0, nodes=22039
# Episode 47: actions=921, score=330.0, nodes=22786
# Episode 48: actions=1075, score=810.0, nodes=22786
# Episode 49: actions=868, score=420.0, nodes=23182
# Episode 50: actions=1075, score=810.0, nodes=23182
# Episode 51: actions=1075, score=810.0, nodes=23182
# Episode 52: actions=1113, score=790.0, nodes=23353
# Episode 53: actions=813, score=420.0, nodes=23387
# Episode 54: actions=770, score=380.0, nodes=23766
# Episode 55: actions=1062, score=690.0, nodes=24059
# Episode 56: actions=1122, score=690.0, nodes=24488
# Episode 57: actions=788, score=510.0, nodes=25093
# Episode 58: actions=1031, score=320.0, nodes=26014
# Episode 59: actions=1075, score=810.0, nodes=26014
# Episode 60: actions=715, score=360.0, nodes=26452
# Episode 61: actions=1048, score=740.0, nodes=26621
# Episode 62: actions=769, score=300.0, nodes=27138
# Episode 63: actions=1075, score=810.0, nodes=27138
# Episode 64: actions=1075, score=810.0, nodes=27158
# Episode 65: actions=1075, score=810.0, nodes=27158
# Episode 66: actions=1041, score=790.0, nodes=27316
# Episode 67: actions=1034, score=750.0, nodes=27636
# Episode 68: actions=1065, score=780.0, nodes=27717
# Episode 69: actions=1095, score=700.0, nodes=28020
# Episode 70: actions=1132, score=770.0, nodes=28402
# Episode 71: actions=775, score=460.0, nodes=29080
# Episode 72: actions=1083, score=770.0, nodes=29472
# Episode 73: actions=1075, score=810.0, nodes=29472
# Episode 74: actions=1075, score=810.0, nodes=29472
# Episode 75: actions=1075, score=810.0, nodes=29472
# Episode 76: actions=1075, score=810.0, nodes=29472
# Episode 77: actions=748, score=440.0, nodes=29782
# Episode 78: actions=1075, score=810.0, nodes=29782
# Episode 79: actions=754, score=300.0, nodes=30258
# Episode 80: actions=1075, score=810.0, nodes=30258
# Episode 81: actions=913, score=510.0, nodes=30721
# Episode 82: actions=809, score=260.0, nodes=31464
# Episode 83: actions=824, score=480.0, nodes=31993
# Episode 84: actions=769, score=330.0, nodes=32658
# Episode 85: actions=1075, score=690.0, nodes=32907
# Episode 86: actions=1083, score=830.0, nodes=32957
# Episode 87: actions=1071, score=750.0, nodes=33056
# Episode 88: actions=796, score=360.0, nodes=33599
# Episode 89: actions=1083, score=830.0, nodes=33599
# Episode 90: actions=1064, score=470.0, nodes=34009
# Episode 91: actions=1083, score=830.0, nodes=34009
# Episode 92: actions=1127, score=680.0, nodes=34292
# Episode 93: actions=1083, score=830.0, nodes=34292
# Episode 94: actions=1065, score=470.0, nodes=34737
# Episode 95: actions=1068, score=790.0, nodes=34791
# Episode 96: actions=770, score=300.0, nodes=35507
# Episode 97: actions=1083, score=830.0, nodes=35507
# Episode 98: actions=779, score=300.0, nodes=36270
# Episode 99: actions=1083, score=830.0, nodes=36270
# Episode 100: actions=1083, score=830.0, nodes=36270
# Episode 101: actions=1071, score=770.0, nodes=36567
# Episode 102: actions=788, score=350.0, nodes=36916
# Episode 103: actions=1083, score=830.0, nodes=36916
# Episode 104: actions=739, score=430.0, nodes=37256
# Episode 105: actions=807, score=320.0, nodes=37844
# Episode 106: actions=1051, score=800.0, nodes=37898
# Episode 107: actions=1083, score=830.0, nodes=37898
# Episode 108: actions=829, score=470.0, nodes=38726
# Episode 109: actions=1083, score=830.0, nodes=38726
# Episode 110: actions=1083, score=830.0, nodes=38726
# Episode 111: actions=972, score=530.0, nodes=39389
# Episode 112: actions=793, score=240.0, nodes=39912
# Episode 113: actions=1083, score=830.0, nodes=39912
# Episode 114: actions=1083, score=830.0, nodes=39912
# Episode 115: actions=1083, score=830.0, nodes=39912
# Episode 116: actions=941, score=500.0, nodes=40352
# Episode 117: actions=1083, score=830.0, nodes=40352
# Episode 118: actions=715, score=430.0, nodes=40829
# Episode 119: actions=1083, score=830.0, nodes=40829
# Episode 120: actions=1083, score=830.0, nodes=40829
# Episode 121: actions=1083, score=830.0, nodes=40829
# Episode 122: actions=1134, score=740.0, nodes=41094
# Episode 123: actions=1083, score=830.0, nodes=41094
# Episode 124: actions=1121, score=710.0, nodes=41372
# Episode 125: actions=1083, score=830.0, nodes=41372
# Episode 126: actions=1083, score=830.0, nodes=41372
# Episode 127: actions=914, score=450.0, nodes=42242
# Episode 128: actions=940, score=410.0, nodes=43155
# Episode 129: actions=1083, score=830.0, nodes=43155
# Episode 130: actions=1083, score=830.0, nodes=43155
# Episode 131: actions=1041, score=510.0, nodes=43543
# Episode 132: actions=913, score=350.0, nodes=44140
# Episode 133: actions=806, score=440.0, nodes=44535
# Episode 134: actions=1083, score=830.0, nodes=44535
# Episode 135: actions=1083, score=830.0, nodes=44535
# Episode 136: actions=886, score=370.0, nodes=44887
# Episode 137: actions=731, score=220.0, nodes=45495
# Episode 138: actions=1067, score=790.0, nodes=45564
# Episode 139: actions=1083, score=830.0, nodes=45564
# Episode 140: actions=1016, score=490.0, nodes=46562
# Episode 141: actions=959, score=530.0, nodes=47277
# Episode 142: actions=1083, score=830.0, nodes=47277
# Episode 143: actions=1083, score=830.0, nodes=47277
# Episode 144: actions=920, score=350.0, nodes=47663
# Episode 145: actions=1036, score=470.0, nodes=48042
# Episode 146: actions=1083, score=830.0, nodes=48042
# Episode 147: actions=1082, score=820.0, nodes=48150
# Episode 148: actions=773, score=270.0, nodes=48597
# Episode 149: actions=760, score=400.0, nodes=49153
# Episode 150: actions=1192, score=470.0, nodes=49742
# Episode 151: actions=1059, score=740.0, nodes=50046
# Episode 152: actions=859, score=270.0, nodes=50825
# Episode 153: actions=1083, score=830.0, nodes=50825
# Episode 154: actions=879, score=340.0, nodes=51151
# Episode 155: actions=1083, score=830.0, nodes=51151
# Episode 156: actions=1059, score=500.0, nodes=51606
# Episode 157: actions=1007, score=400.0, nodes=52413
# Episode 158: actions=1083, score=830.0, nodes=52413
# Episode 159: actions=1083, score=830.0, nodes=52413
# Episode 160: actions=1034, score=500.0, nodes=52909
# Episode 161: actions=908, score=500.0, nodes=53779
# Episode 162: actions=1083, score=830.0, nodes=53779
# Episode 163: actions=834, score=400.0, nodes=54239
# Episode 164: actions=1006, score=520.0, nodes=54716
# Episode 165: actions=806, score=370.0, nodes=55471
# Episode 166: actions=1083, score=830.0, nodes=55471
# Episode 167: actions=1083, score=830.0, nodes=55471
# Episode 168: actions=1067, score=520.0, nodes=55966
# Episode 169: actions=1083, score=830.0, nodes=55966
# Episode 170: actions=753, score=380.0, nodes=56314
# Episode 171: actions=949, score=510.0, nodes=56977
# Episode 172: actions=1115, score=820.0, nodes=57165
# Episode 173: actions=840, score=400.0, nodes=57813
# Episode 174: actions=912, score=580.0, nodes=58448
# Episode 175: actions=1087, score=670.0, nodes=58842
# Episode 176: actions=1083, score=830.0, nodes=58878
# Episode 177: actions=839, score=370.0, nodes=59168
# Episode 178: actions=1008, score=720.0, nodes=59503
# Episode 179: actions=1074, score=560.0, nodes=60063
# Episode 180: actions=1061, score=700.0, nodes=60307
# Episode 181: actions=785, score=330.0, nodes=60769
# Episode 182: actions=1220, score=890.0, nodes=61236
# Episode 183: actions=1080, score=680.0, nodes=61414
# Episode 184: actions=1209, score=900.0, nodes=61710
# Episode 185: actions=1074, score=710.0, nodes=62034
# Episode 186: actions=764, score=340.0, nodes=62661
# Episode 187: actions=1079, score=750.0, nodes=62792
# Episode 188: actions=940, score=570.0, nodes=63219
# Episode 189: actions=1209, score=900.0, nodes=63219
# Episode 190: actions=1071, score=720.0, nodes=63362
# Episode 191: actions=807, score=440.0, nodes=63837
# Episode 192: actions=1043, score=720.0, nodes=64119
# Episode 193: actions=1209, score=900.0, nodes=64119
# Episode 194: actions=1209, score=900.0, nodes=64119
# Episode 195: actions=1209, score=900.0, nodes=64119
# Episode 196: actions=1209, score=900.0, nodes=64119
# Episode 197: actions=1209, score=900.0, nodes=64119
# Episode 198: actions=1209, score=900.0, nodes=64119
# Episode 199: actions=846, score=280.0, nodes=64670
# Episode 200: actions=730, score=330.0, nodes=64942
# Episode 201: actions=1047, score=760.0, nodes=65157
# Episode 202: actions=1209, score=900.0, nodes=65157
# Episode 203: actions=1204, score=910.0, nodes=65233
# Episode 204: actions=723, score=250.0, nodes=65945
# Episode 205: actions=1201, score=860.0, nodes=66121
# Episode 206: actions=1146, score=630.0, nodes=66466
# Episode 207: actions=1062, score=810.0, nodes=66843
# Episode 208: actions=1204, score=910.0, nodes=66843
# Episode 209: actions=923, score=500.0, nodes=67607
# Episode 210: actions=1204, score=910.0, nodes=67607
# Episode 211: actions=824, score=440.0, nodes=68416
# Episode 212: actions=1100, score=700.0, nodes=68610
# Episode 213: actions=1204, score=910.0, nodes=68610
# Episode 214: actions=1204, score=910.0, nodes=68610
# Episode 215: actions=1204, score=910.0, nodes=68610
# Episode 216: actions=1075, score=690.0, nodes=68814
# Episode 217: actions=1204, score=910.0, nodes=68814
# Episode 218: actions=1016, score=560.0, nodes=69554
# Episode 219: actions=1204, score=910.0, nodes=69554
# Episode 220: actions=1227, score=910.0, nodes=69698
# Episode 221: actions=1058, score=780.0, nodes=70005
# Episode 222: actions=747, score=350.0, nodes=70516
# Episode 223: actions=794, score=350.0, nodes=71185
# Episode 224: actions=829, score=410.0, nodes=71552
# Episode 225: actions=1083, score=530.0, nodes=72065
# Episode 226: actions=1227, score=910.0, nodes=72065
# Episode 227: actions=1227, score=910.0, nodes=72065
# Episode 228: actions=1204, score=910.0, nodes=72065
# Episode 229: actions=834, score=300.0, nodes=72783
# Episode 230: actions=966, score=450.0, nodes=73326
# Episode 231: actions=799, score=310.0, nodes=74069
# Episode 232: actions=1208, score=860.0, nodes=74218
# Episode 233: actions=1238, score=910.0, nodes=74321
# Episode 234: actions=765, score=390.0, nodes=74635
# Episode 235: actions=1204, score=910.0, nodes=74635
# Episode 236: actions=1060, score=760.0, nodes=74787
# Episode 237: actions=1204, score=910.0, nodes=74787
# Episode 238: actions=845, score=230.0, nodes=75597
# Episode 239: actions=1204, score=910.0, nodes=75597
# Episode 240: actions=1136, score=500.0, nodes=76138
# Episode 241: actions=1041, score=730.0, nodes=76511
# Episode 242: actions=1227, score=910.0, nodes=76549
# Episode 243: actions=772, score=290.0, nodes=77094
# Episode 244: actions=1057, score=780.0, nodes=77239
# Episode 245: actions=1238, score=910.0, nodes=77239
# Episode 246: actions=1204, score=910.0, nodes=77239
# Episode 247: actions=1204, score=910.0, nodes=77239
# Episode 248: actions=1237, score=940.0, nodes=77337
# Episode 249: actions=1237, score=940.0, nodes=77364
# Episode 250: actions=1237, score=940.0, nodes=77364
# --------------------------------------------------------------------------------
# 250 episodes ran and took 701.2325 seconds
# Episode 248 had the best score of 940.0.
# Converting frames to .AVI ... Done. Saved to /content/drive/My Drive/Colab Notebooks/250 - Brute_MsPacMan-Nes_E248_03_09_2020_163342.avi
# Saving log ... Done. Saved to /content/drive/My Drive/Colab Notebooks/250 - Brute_MsPacMan-Nes.log
